# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(10)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
# 6                  14      NaN        NaN            NaN             Germany
# 7                  18  Monthly        NaN            NaN               India
# 8                  12   Yearly   116000.0       116000.0       United States
# 9                  20      NaN        NaN            NaN             Tunisia
# 10                 14   Yearly    25000.0        32315.0      United Kingdom
#
#                     CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                  European Euro            EUR   Microsoft SQL Server
# 2                 Pound sterling            GBP                    NaN
# 3                            NaN            NaN                    NaN
# 4                   Albanian lek            ALL                    NaN
# 5                            NaN            NaN       MySQL;PostgreSQL
# 6                  European Euro            EUR                    NaN
# 7           United States dollar            USD                    NaN
# 8           United States dollar            USD                MongoDB
# 9           United States dollar            USD                    NaN
# 10                Pound sterling            GBP   Microsoft SQL Server
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                       MySQL;PostgreSQL;Redis;SQLite
# 6                                                 NaN
# 7                                                 NaN
# 8                                 MariaDB;MySQL;Redis
# 9                                                 NaN
# 10                               Microsoft SQL Server
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# 6             Designer;Developer, front-end;Developer, mobile
# 7           Developer, back-end;Developer, front-end;Devel...
# 8           Developer, back-end;Developer, desktop or ente...
# 9                                       Developer, full-stack
# 10          Database administrator;Developer, full-stack;D...
#
#                                                       EdLevel  \
# Respondent
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                         NaN
# 4             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6           Secondary school (e.g. American high school, G...
# 7                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9                          Professional degree (JD, MD, etc.)
# 10            Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
# 4                                                         NaN
# 5                                          Employed full-time
# 6                                          Employed full-time
# 7                                          Employed full-time
# 8                                          Employed full-time
# 9           Independent contractor, freelancer, or self-em...
# 10                                         Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
# 4           White or of European descent    Man
# 5           White or of European descent    Man
# 6           White or of European descent    Man
# 7                                    NaN    NaN
# 8           White or of European descent    Man
# 9                                    NaN    Man
# 10          White or of European descent    Man
#
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 2                                                         NaN
# 3                                                         NaN
# 4           Flex time or a flexible schedule;Office enviro...
# 5                                                         NaN
# 6           Diversity of the company or organization;Langu...
# 7                                                         NaN
# 8           Remote work options;Opportunities for professi...
# 9           Diversity of the company or organization;Remot...
# 10          Flex time or a flexible schedule;How widely us...
#
#                            JobSat  \
# Respondent
# 1              Slightly satisfied
# 2               Very dissatisfied
# 3                             NaN
# 4           Slightly dissatisfied
# 5                             NaN
# 6              Slightly satisfied
# 7                  Very satisfied
# 8           Slightly dissatisfied
# 9               Very dissatisfied
# 10                 Very satisfied
#
#                                                       JobSeek  \
# Respondent
# 1                I am not interested in new job opportunities
# 2                I am not interested in new job opportunities
# 3                                                         NaN
# 4           I’m not actively looking, but I am open to new...
# 5                                                         NaN
# 6                I am not interested in new job opportunities
# 7           I’m not actively looking, but I am open to new...
# 8           I’m not actively looking, but I am open to new...
# 9           I’m not actively looking, but I am open to new...
# 10          I’m not actively looking, but I am open to new...
#
#                            LanguageDesireNextYear  \
# Respondent
# 1                          C#;HTML/CSS;JavaScript
# 2                                    Python;Swift
# 3                        Objective-C;Python;Swift
# 4                                             NaN
# 5                                 Java;Ruby;Scala
# 6                        HTML/CSS;Java;JavaScript
# 7                                 C#;HTML/CSS;PHP
# 8                                      JavaScript
# 9                                     Python;Rust
# 10          HTML/CSS;Java;JavaScript;Python;R;SQL
#
#                              LanguageWorkedWith  \
# Respondent
# 1                        C#;HTML/CSS;JavaScript
# 2                              JavaScript;Swift
# 3                      Objective-C;Python;Swift
# 4                                           NaN
# 5                             HTML/CSS;Ruby;SQL
# 6                      HTML/CSS;Java;JavaScript
# 7                               C#;HTML/CSS;PHP
# 8                                    Python;SQL
# 9                       HTML/CSS;JavaScript;PHP
# 10          HTML/CSS;Java;JavaScript;Python;SQL
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
# 6                                        NaN                NaN
# 7                                        NaN                NaN
# 8                                   Unity 3D            Ansible
# 9                                        NaN                NaN
# 10                         Pandas;TensorFlow             Pandas
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
# 6                                     Github;Slack
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                          Github;Microsoft Teams
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# 6                              Confluence;Github;Slack;Trello  Not sure
# 7                                                         NaN       Yes
# 8           Confluence;Jira;Github;Slack;Microsoft Teams;G...       Yes
# 9           Github;Slack;Trello;Google Suite (Docs, Meet, ...       NaN
# 10                                     Github;Microsoft Teams        No
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 1            Somewhat important                    Fairly important
# 2                           NaN                    Fairly important
# 3                           NaN                                 NaN
# 4                           NaN  Not at all important/not necessary
# 5                           NaN                      Very important
# 6                           NaN                    Fairly important
# 7           Extremely important                      Very important
# 8           Extremely important  Not at all important/not necessary
# 9                           NaN                      Very important
# 10                      Neutral                    Fairly important
#
#                                                    NEWJobHunt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
# 6                                                         NaN
# 7           Better compensation;Growth or leadership oppor...
# 8           Curious about other opportunities;Better compe...
# 9           Curious about other opportunities;Growth or le...
# 10          Curious about other opportunities;Better compe...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# 6                                                         NaN
# 7           Read company media, such as employee blogs or ...
# 8           Read company media, such as employee blogs or ...
# 9                                                         NaN
# 10          Company reviews from third party sites (e.g. G...
#
#                     NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 1                Once a year    Not sure                           NaN
# 2                Once a year    Not sure                           NaN
# 3              Once a decade         NaN                           NaN
# 4                Once a year    Not sure                           Yes
# 5                Once a year          No                           NaN
# 6                Once a year          No                            No
# 7           Every few months         Yes                           Yes
# 8                Once a year    Not sure                           Yes
# 9                Once a year          No                           Yes
# 10          Every few months         Yes  Onboarding? What onboarding?
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 1                     No                   Often: 1-2 days per week or more
# 2                     No                                                NaN
# 3                     No                                                NaN
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 5                    Yes                                                NaN
# 6                     No                                              Never
# 7                     No  Sometimes: 1-2 days per month but less than we...
# 8                     No  Occasionally: 1-2 days per quarter but less th...
# 9                     No  Occasionally: 1-2 days per quarter but less th...
# 10                    No                   Often: 1-2 days per week or more
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
# 6           Ask developers I know/work with;Read ratings o...
# 7           Start a free trial;Ask developers I know/work ...
# 8           Start a free trial;Ask developers I know/work ...
# 9                                          Start a free trial
# 10          Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
# 6                      Amused
# 7                         NaN
# 8           Hello, old friend
# 9           Hello, old friend
# 10          Hello, old friend
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
# 6           Stack Overflow (public Q&A for anyone who code...
# 7            Stack Overflow (public Q&A for anyone who codes)
# 8           Stack Overflow (public Q&A for anyone who code...
# 9           Stack Overflow (public Q&A for anyone who code...
# 10          Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
# 6           Play games;Visit Stack Overflow;Watch help / t...      Windows
# 7                                                         NaN      Windows
# 8           Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 9                                                    Meditate      Windows
# 10                                       Visit Stack Overflow      Windows
#
#                                                       OrgSize  \
# Respondent
# 1                                            2 to 9 employees
# 2                                    1,000 to 4,999 employees
# 3                                                         NaN
# 4                                          20 to 99 employees
# 5                                                         NaN
# 6                                                         NaN
# 7                                          20 to 99 employees
# 8                                          20 to 99 employees
# 9           Just me - I am a freelancer, sole proprietor, ...
# 10                                           2 to 9 employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
# 6                                                     Android
# 7                                                         NaN
# 8                             iOS;Slack Apps and Integrations
# 9                                                         NaN
# 10                         Android;Linux;Raspberry Pi;Windows
#
#                             PlatformWorkedWith  \
# Respondent
# 1                                      Windows
# 2                                          iOS
# 3                                          NaN
# 4                                          NaN
# 5               AWS;Docker;Linux;MacOS;Windows
# 6                     Android;Docker;WordPress
# 7                                          NaN
# 8                                       Docker
# 9                                    WordPress
# 10          Android;Linux;Raspberry Pi;Windows
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 1                                        NaN  Straight / Heterosexual
# 2              I have little or no influence                      NaN
# 3                                        NaN                      NaN
# 4           I have a great deal of influence  Straight / Heterosexual
# 5                                        NaN  Straight / Heterosexual
# 6                      I have some influence  Straight / Heterosexual
# 7                                        NaN                      NaN
# 8                      I have some influence  Straight / Heterosexual
# 9                                        NaN  Straight / Heterosexual
# 10          I have a great deal of influence  Straight / Heterosexual
#
#            SOAccount           SOComm                           SOPartFreq  \
# Respondent
# 1                 No   No, not at all                                  NaN
# 2                Yes  Yes, definitely  Less than once per month or monthly
# 3                Yes    Yes, somewhat      A few times per month or weekly
# 4                Yes  Yes, definitely      A few times per month or weekly
# 5                Yes    Yes, somewhat  Less than once per month or monthly
# 6                Yes    Yes, somewhat      A few times per month or weekly
# 7                Yes  Yes, definitely               Multiple times per day
# 8                Yes   No, not really  Less than once per month or monthly
# 9                Yes  Yes, definitely               Multiple times per day
# 10               Yes  Yes, definitely               Multiple times per day
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
# 6                      A few times per week  Neither easy nor difficult
# 7                    Multiple times per day                         NaN
# 8                    Multiple times per day                        Easy
# 9                    Multiple times per day  Neither easy nor difficult
# 10                   Multiple times per day                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
# 6           Appropriate in length   NaN
# 7                             NaN   NaN
# 8           Appropriate in length    No
# 9           Appropriate in length    No
# 10          Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 6                                                         NaN
# 7           Computer science, computer engineering, or sof...
# 8           Computer science, computer engineering, or sof...
# 9           Computer science, computer engineering, or sof...
# 10                                  Mathematics or statistics
#
#             WebframeDesireNextYear    WebframeWorkedWith  \
# Respondent
# 1                     ASP.NET Core  ASP.NET;ASP.NET Core
# 2                              NaN                   NaN
# 3                              NaN                   NaN
# 4                              NaN                   NaN
# 5             Django;Ruby on Rails         Ruby on Rails
# 6                         React.js                   NaN
# 7                              NaN                   NaN
# 8           Django;React.js;Vue.js                 Flask
# 9                       Angular.js                jQuery
# 10                    Flask;jQuery          Flask;jQuery
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
# 6                                                NaN          NaN         6
# 7              A lot more welcome now than last year          NaN         6
# 8            Just as welcome now as I felt last year         39.0        17
# 9            Just as welcome now as I felt last year         50.0         6
# 10          Somewhat more welcome now than last year         36.0         8
#
#            YearsCodePro
# Respondent
# 1                    27
# 2                     4
# 3                   NaN
# 4                     4
# 5                     8
# 6                     4
# 7                     4
# 8                    13
# 9                     4
# 10                    4

# %%
high_salary=df['CompTotal']>25000

# %%
df.loc[high_salary,['CompTotal','Country','LanguageWorkedWith','Age']].head(50)
# Out:
#              CompTotal         Country  \
# Respondent
# 8             116000.0   United States
# 11             31000.0  United Kingdom
# 14             66000.0   United States
# 17             79000.0   United States
# 18            105000.0   United States
# 19             83400.0   United States
# 24             85000.0         Germany
# 26             94000.0          Canada
# 30             30000.0  United Kingdom
# 36             60000.0  United Kingdom
# 38             90000.0           Italy
# 41            106000.0   United States
# 42            130000.0   United States
# 43            135000.0   United States
# 44            244000.0          Brazil
# 45             34000.0          France
# 46             35000.0          France
# 47             58000.0  United Kingdom
# 48            125000.0   United States
# 49             52000.0   United States
# 51            137000.0          Canada
# 52             70000.0  United Kingdom
# 54            160000.0   United States
# 57            135000.0   United States
# 64             73000.0  United Kingdom
# 65             98000.0   United States
# 67            250000.0   United States
# 69            550000.0          France
# 79             50000.0          Canada
# 80             94500.0   United States
# 82            117000.0   United States
# 89            130000.0   United States
# 91          70000000.0       Indonesia
# 92             53000.0          France
# 94             50000.0          Canada
# 95             95000.0          Canada
# 97            100000.0          Canada
# 98             80000.0  Czech Republic
# 99            105000.0          Canada
# 100            93000.0   United States
# 105            40000.0   United States
# 107           148000.0   United States
# 110           130000.0   United States
# 112            65000.0   United States
# 115            78800.0   United States
# 117            90000.0  United Kingdom
# 119           145000.0   United States
# 120            57000.0         Germany
# 121           145000.0   United States
# 122            85000.0  United Kingdom
#
#                                            LanguageWorkedWith   Age
# Respondent
# 8                                                  Python;SQL  36.0
# 11                                        C#;JavaScript;Swift  23.0
# 14                         HTML/CSS;JavaScript;SQL;TypeScript  27.0
# 17                      C#;HTML/CSS;JavaScript;Python;SQL;VBA  25.0
# 18                        Bash/Shell/PowerShell;HTML/CSS;Perl  32.0
# 19          Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...  24.0
# 24                  Bash/Shell/PowerShell;Java;Kotlin;PHP;SQL  45.0
# 26                                          JavaScript;Python   NaN
# 30          Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...   NaN
# 36                C#;Go;HTML/CSS;Java;JavaScript;Python;R;SQL  34.0
# 38                       HTML/CSS;JavaScript;Python;Ruby;Rust  35.0
# 41                                              C;C#;Java;SQL   NaN
# 42          Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...  32.0
# 43                          Dart;HTML/CSS;Java;JavaScript;SQL   NaN
# 44                                  HTML/CSS;Python;R;SQL;VBA  32.0
# 45          Bash/Shell/PowerShell;C;C++;Java;JavaScript;Py...  22.0
# 46                               Bash/Shell/PowerShell;C#;C++  24.0
# 47          Bash/Shell/PowerShell;C#;Java;JavaScript;Pytho...  53.0
# 48                                        JavaScript;Ruby;SQL  38.0
# 49                          C#;HTML/CSS;JavaScript;TypeScript  23.0
# 51                           JavaScript;Python;SQL;TypeScript   NaN
# 52                                                Java;Kotlin  28.0
# 54                                     C#;HTML/CSS;JavaScript  44.0
# 57                                                     C#;VBA  44.0
# 64                               HTML/CSS;JavaScript;Perl;SQL  34.0
# 65           Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;SQL  34.0
# 67                                   HTML/CSS;JavaScript;Ruby  35.0
# 69                                            HTML/CSS;Python  25.0
# 79                                HTML/CSS;JavaScript;PHP;SQL  28.0
# 80          Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...  32.0
# 82                                 C#;HTML/CSS;JavaScript;SQL  48.0
# 89                      C#;HTML/CSS;JavaScript;SQL;TypeScript  28.0
# 91                        HTML/CSS;JavaScript;Ruby;TypeScript  28.0
# 92            Bash/Shell/PowerShell;C;Java;JavaScript;PHP;SQL  31.0
# 94                    Bash/Shell/PowerShell;C;Python;Ruby;SQL  21.0
# 95                         HTML/CSS;JavaScript;PHP;Python;SQL   NaN
# 97          Bash/Shell/PowerShell;Go;Java;JavaScript;Rust;...  30.0
# 98                                                 C++;Python  29.0
# 99                        Go;JavaScript;Python;SQL;TypeScript  30.0
# 100                                C#;HTML/CSS;JavaScript;SQL  42.0
# 105                     C#;HTML/CSS;JavaScript;SQL;TypeScript  28.0
# 107         Bash/Shell/PowerShell;HTML/CSS;JavaScript;Rust...  29.0
# 110         Bash/Shell/PowerShell;C;C++;Go;HTML/CSS;Java;J...  45.0
# 112                                                Python;SQL  28.0
# 115                            Assembly;C;C++;Java;Python;SQL  23.0
# 117         Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...  30.0
# 119         Bash/Shell/PowerShell;C#;Go;HTML/CSS;Java;Java...  35.0
# 120                                             Go;PHP;Python  24.0
# 121               Bash/Shell/PowerShell;JavaScript;Python;SQL  26.0
# 122         Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...  23.0

# %%
countries=['Germany','Japan','India','United States']
filt=df['Country'].isin(countries)

# %%
df.loc[filt,'Country'].head(60)
# Out:
# Respondent
# 1            Germany
# 5      United States
# 6            Germany
# 7              India
# 8      United States
# 14     United States
# 17     United States
# 18     United States
# 19     United States
# 22             India
# 23           Germany
# 24           Germany
# 27     United States
# 34           Germany
# 35     United States
# 40     United States
# 41     United States
# 42     United States
# 43     United States
# 48     United States
# 49     United States
# 53     United States
# 54     United States
# 55     United States
# 56     United States
# 57     United States
# 58             India
# 60           Germany
# 63             India
# 65     United States
# 67     United States
# 68     United States
# 72     United States
# 76     United States
# 77     United States
# 80     United States
# 81     United States
# 82     United States
# 84     United States
# 85     United States
# 89     United States
# 100    United States
# 101    United States
# 103    United States
# 105    United States
# 106          Germany
# 107    United States
# 109    United States
# 110    United States
# 111          Germany
# 112    United States
# 113    United States
# 115    United States
# 119    United States
# 120          Germany
# 121    United States
# 123    United States
# 124    United States
# 125    United States
# 126    United States
# Name: Country, dtype: object

# %%
filt=df['LanguageWorkedWith'].str.contains('Python',na=False)

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
filt
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 64858    False
# 64867     True
# 64898    False
# 64925    False
# 65112    False
# Name: LanguageWorkedWith, Length: 64461, dtype: bool

# %%
df[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 3                                 I code primarily as a hobby      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 10                             I am a developer by profession      Yes  22.0
# 13          I am not primarily a developer, but I write co...      Yes  53.0
# 15                     I am a student who is learning to code      Yes   NaN
# ...                                                       ...      ...   ...
# 61561                                                     NaN      Yes  64.0
# 62391                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 63640                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
#
#                       Age1stCode CompFreq  CompTotal  ConvertedComp  \
# Respondent
# 3                             15      NaN        NaN            NaN
# 8                             12   Yearly   116000.0       116000.0
# 10                            14   Yearly    25000.0        32315.0
# 13                            14  Monthly     3000.0        38916.0
# 15                            13      NaN        NaN            NaN
# ...                          ...      ...        ...            ...
# 61561                         18      NaN        NaN            NaN
# 62391       Younger than 5 years      NaN        NaN            NaN
# 63077                         20      NaN        NaN            NaN
# 63640                          8      NaN        NaN            NaN
# 64867                        NaN      NaN        NaN            NaN
#
#                        Country          CurrencyDesc CurrencySymbol  \
# Respondent
# 3           Russian Federation                   NaN            NaN
# 8                United States  United States dollar            USD
# 10              United Kingdom        Pound sterling            GBP
# 13                 Netherlands         European Euro            EUR
# 15                      France                   NaN            NaN
# ...                        ...                   ...            ...
# 61561                   France                   NaN            NaN
# 62391                  Morocco                   NaN            NaN
# 63077            United States                   NaN            NaN
# 63640                Australia                   NaN            NaN
# 64867                  Morocco                   NaN            NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 3                                                         NaN
# 8                                                     MongoDB
# 10                                       Microsoft SQL Server
# 13                                                        NaN
# 15                                                        NaN
# ...                                                       ...
# 61561                                            MySQL;Oracle
# 62391                            Elasticsearch;IBM DB2;Oracle
# 63077                                                   MySQL
# 63640       Firebase;Microsoft SQL Server;MongoDB;MySQL;Po...
# 64867       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
#
#                                            DatabaseWorkedWith  \
# Respondent
# 3                                                         NaN
# 8                                         MariaDB;MySQL;Redis
# 10                                       Microsoft SQL Server
# 13                                                        NaN
# 15                                               MySQL;Oracle
# ...                                                       ...
# 61561                                            MySQL;Oracle
# 62391                          Cassandra;Microsoft SQL Server
# 63077                                                   MySQL
# 63640                                                 MongoDB
# 64867       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
#
#                                                       DevType  \
# Respondent
# 3                                                         NaN
# 8           Developer, back-end;Developer, desktop or ente...
# 10          Database administrator;Developer, full-stack;D...
# 13                               Designer;Developer, back-end
# 15                                                        NaN
# ...                                                       ...
# 61561                                                     NaN
# 62391                                                     NaN
# 63077                                                     NaN
# 63640       Academic researcher;Data or business analyst;D...
# 64867                                                     NaN
#
#                                                       EdLevel  \
# Respondent
# 3                                                         NaN
# 8                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 10            Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 13          Secondary school (e.g. American high school, G...
# 15               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 61561                                                     NaN
# 62391                               Primary/elementary school
# 63077            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 63640                               Primary/elementary school
# 64867                                                     NaN
#
#                                                    Employment  \
# Respondent
# 3                                                         NaN
# 8                                          Employed full-time
# 10                                         Employed full-time
# 13                                         Employed full-time
# 15                                                    Student
# ...                                                       ...
# 61561                                                 Retired
# 62391                                                     NaN
# 63077                      Not employed, but looking for work
# 63640       Independent contractor, freelancer, or self-em...
# 64867                                      Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 3                                    NaN    NaN
# 8           White or of European descent    Man
# 10          White or of European descent    Man
# 13          White or of European descent    Man
# 15                                   NaN    Man
# ...                                  ...    ...
# 61561       White or of European descent    Man
# 62391                                NaN    Man
# 63077                                NaN    NaN
# 63640                                NaN    Man
# 64867                                NaN    NaN
#
#                                                    JobFactors  \
# Respondent
# 3                                                         NaN
# 8           Remote work options;Opportunities for professi...
# 10          Flex time or a flexible schedule;How widely us...
# 13          Industry that I’d be working in;Financial perf...
# 15          Languages, frameworks, and other technologies ...
# ...                                                       ...
# 61561                                                     NaN
# 62391                                                     NaN
# 63077                                                     NaN
# 63640                                                     NaN
# 64867                                                     NaN
#
#                            JobSat  \
# Respondent
# 3                             NaN
# 8           Slightly dissatisfied
# 10                 Very satisfied
# 13                 Very satisfied
# 15                            NaN
# ...                           ...
# 61561                         NaN
# 62391                         NaN
# 63077                         NaN
# 63640                         NaN
# 64867                         NaN
#
#                                                       JobSeek  \
# Respondent
# 3                                                         NaN
# 8           I’m not actively looking, but I am open to new...
# 10          I’m not actively looking, but I am open to new...
# 13               I am not interested in new job opportunities
# 15          I’m not actively looking, but I am open to new...
# ...                                                       ...
# 61561                                                     NaN
# 62391                                                     NaN
# 63077                                                     NaN
# 63640                                                     NaN
# 64867                                                     NaN
#
#                                        LanguageDesireNextYear  \
# Respondent
# 3                                    Objective-C;Python;Swift
# 8                                                  JavaScript
# 10                      HTML/CSS;Java;JavaScript;Python;R;SQL
# 13                                                     Python
# 15                        Assembly;Bash/Shell/PowerShell;C;Go
# ...                                                       ...
# 61561       Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;P...
# 62391                                                     NaN
# 63077                                            C++;Rust;SQL
# 63640       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
#
#                                            LanguageWorkedWith  \
# Respondent
# 3                                    Objective-C;Python;Swift
# 8                                                  Python;SQL
# 10                        HTML/CSS;Java;JavaScript;Python;SQL
# 13                                        C;JavaScript;Python
# 15           Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
# ...                                                       ...
# 61561       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391          C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077                 C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640       Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 3                                                         NaN
# 8                                                    Unity 3D
# 10                                          Pandas;TensorFlow
# 13                                                        NaN
# 15                                                        NaN
# ...                                                       ...
# 61561              Ansible;Apache Spark;Hadoop;Node.js;Puppet
# 62391                                   .NET;Node.js;Unity 3D
# 63077                                                     NaN
# 63640       Flutter;Node.js;React Native;TensorFlow;Unity ...
# 64867                                                     NaN
#
#                         MiscTechWorkedWith  \
# Respondent
# 3                                      NaN
# 8                                  Ansible
# 10                                  Pandas
# 13                                     NaN
# 15                                     NaN
# ...                                    ...
# 61561                                  NaN
# 62391                .NET;Node.js;Unity 3D
# 63077                                  NaN
# 63640       Node.js;Unity 3D;Unreal Engine
# 64867                                  NaN
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 3                                                         NaN
# 8                                                         NaN
# 10                                     Github;Microsoft Teams
# 13                                                        NaN
# 15                                              Github;Gitlab
# ...                                                       ...
# 61561       Github;Gitlab;Google Suite (Docs, Meet, etc);S...
# 62391       Github;Facebook Workplace;Microsoft Azure;Goog...
# 63077                                                     NaN
# 63640       Jira;Github;Slack;Microsoft Teams;Microsoft Az...
# 64867                                                     NaN
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 3                                                         NaN       NaN
# 8           Confluence;Jira;Github;Slack;Microsoft Teams;G...       Yes
# 10                                     Github;Microsoft Teams        No
# 13                                                        NaN        No
# 15                                                     Github       NaN
# ...                                                       ...       ...
# 61561                  Github;Gitlab;Stack Overflow for Teams       NaN
# 62391       Github;Facebook Workplace;Microsoft Azure;Goog...       NaN
# 63077                                                     NaN       NaN
# 63640       Github;Slack;Microsoft Azure;Google Suite (Doc...       NaN
# 64867                                                     NaN       NaN
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 3                           NaN                                 NaN
# 8           Extremely important  Not at all important/not necessary
# 10                      Neutral                    Fairly important
# 13                          NaN  Not at all important/not necessary
# 15                          NaN                                 NaN
# ...                         ...                                 ...
# 61561                       NaN                    Fairly important
# 62391                       NaN                      Very important
# 63077                       NaN                    Fairly important
# 63640                       NaN                Critically important
# 64867                       NaN                                 NaN
#
#                                                    NEWJobHunt  \
# Respondent
# 3                                                         NaN
# 8           Curious about other opportunities;Better compe...
# 10          Curious about other opportunities;Better compe...
# 13                Having a bad day (or week or month) at work
# 15                                                        NaN
# ...                                                       ...
# 61561                                                     NaN
# 62391                                                     NaN
# 63077                                                     NaN
# 63640                                                     NaN
# 64867                                                     NaN
#
#                                            NEWJobHuntResearch  \
# Respondent
# 3                                                         NaN
# 8           Read company media, such as employee blogs or ...
# 10          Company reviews from third party sites (e.g. G...
# 13          Read company media, such as employee blogs or ...
# 15                                                        NaN
# ...                                                       ...
# 61561                                                     NaN
# 62391                                                     NaN
# 63077                                                     NaN
# 63640                                                     NaN
# 64867                                                     NaN
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 3                  Once a decade         NaN                           NaN
# 8                    Once a year    Not sure                           Yes
# 10              Every few months         Yes  Onboarding? What onboarding?
# 13          Once every few years          No                           Yes
# 15          Once every few years         Yes                           NaN
# ...                          ...         ...                           ...
# 61561                Once a year          No                           NaN
# 62391                        NaN         NaN                           NaN
# 63077                        NaN         NaN                           NaN
# 63640           Every few months          No                           NaN
# 64867                        NaN         NaN                           NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 3                     No                                                NaN
# 8                     No  Occasionally: 1-2 days per quarter but less th...
# 10                    No                   Often: 1-2 days per week or more
# 13                    No                  Rarely: 1-2 days per year or less
# 15                    No                                                NaN
# ...                  ...                                                ...
# 61561                NaN                                                NaN
# 62391                NaN                                                NaN
# 63077                NaN                                                NaN
# 63640                NaN                                                NaN
# 64867                NaN                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 3                                                         NaN
# 8           Start a free trial;Ask developers I know/work ...
# 10          Start a free trial;Ask developers I know/work ...
# 13                                         Start a free trial
# 15                            Ask developers I know/work with
# ...                                                       ...
# 61561       Start a free trial;Ask developers I know/work ...
# 62391                                      Start a free trial
# 63077                                                     NaN
# 63640       Start a free trial;Ask developers I know/work ...
# 64867                                                     NaN
#
#                 NEWPurpleLink  \
# Respondent
# 3                         NaN
# 8           Hello, old friend
# 10          Hello, old friend
# 13                     Amused
# 15                    Annoyed
# ...                       ...
# 61561                  Amused
# 62391       Hello, old friend
# 63077                     NaN
# 63640             Indifferent
# 64867                     NaN
#
#                                                    NEWSOSites  \
# Respondent
# 3            Stack Overflow (public Q&A for anyone who codes)
# 8           Stack Overflow (public Q&A for anyone who code...
# 10          Stack Overflow (public Q&A for anyone who code...
# 13          Stack Overflow (public Q&A for anyone who code...
# 15          Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 61561        Stack Overflow (public Q&A for anyone who codes)
# 62391       Stack Overflow Advertising (for technology com...
# 63077        Stack Overflow (public Q&A for anyone who codes)
# 63640        Stack Overflow (public Q&A for anyone who codes)
# 64867                                                     NaN
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 3                                                         NaN  Linux-based
# 8           Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 10                                       Visit Stack Overflow      Windows
# 13          Call a coworker or friend;Go for a walk or oth...        MacOS
# 15                      Play games;Visit Stack Overflow;Panic  Linux-based
# ...                                                       ...          ...
# 61561       Visit Stack Overflow;Go for a walk or other ph...          NaN
# 62391        Meditate;Play games;Watch help / tutorial videos      Windows
# 63077                                                     NaN          NaN
# 63640       Call a coworker or friend;Visit Stack Overflow...        MacOS
# 64867                                                     NaN          NaN
#
#                        OrgSize  \
# Respondent
# 3                          NaN
# 8           20 to 99 employees
# 10            2 to 9 employees
# 13            2 to 9 employees
# 15                         NaN
# ...                        ...
# 61561                      NaN
# 62391                      NaN
# 63077                      NaN
# 63640                      NaN
# 64867                      NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 3                                                         NaN
# 8                             iOS;Slack Apps and Integrations
# 10                         Android;Linux;Raspberry Pi;Windows
# 13                                        Linux;MacOS;Windows
# 15                                                      Linux
# ...                                                       ...
# 61561          Android;Arduino;Docker;Linux;Windows;WordPress
# 62391       Android;Docker;Google Cloud Platform;iOS;Linux...
# 63077                                                     NaN
# 63640       Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 64867                                                     NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 3                                                         NaN
# 8                                                      Docker
# 10                         Android;Linux;Raspberry Pi;Windows
# 13                                              MacOS;Windows
# 15                                                      Linux
# ...                                                       ...
# 61561       Arduino;Docker;Linux;Raspberry Pi;Windows;Word...
# 62391       Android;Docker;Google Cloud Platform;iOS;MacOS...
# 63077                                                     NaN
# 63640       AWS;Google Cloud Platform;Heroku;iOS;Linux;Mac...
# 64867                                                     NaN
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 3                                        NaN                      NaN
# 8                      I have some influence  Straight / Heterosexual
# 10          I have a great deal of influence  Straight / Heterosexual
# 13                     I have some influence  Straight / Heterosexual
# 15                                       NaN           Gay or Lesbian
# ...                                      ...                      ...
# 61561                                    NaN  Straight / Heterosexual
# 62391                                    NaN                      NaN
# 63077                                    NaN                      NaN
# 63640                                    NaN  Straight / Heterosexual
# 64867                                    NaN                      NaN
#
#            SOAccount           SOComm  \
# Respondent
# 3                Yes    Yes, somewhat
# 8                Yes   No, not really
# 10               Yes  Yes, definitely
# 13               Yes  Yes, definitely
# 15                No   No, not really
# ...              ...              ...
# 61561            Yes          Neutral
# 62391            NaN              NaN
# 63077            Yes   No, not really
# 63640            Yes    Yes, somewhat
# 64867            NaN              NaN
#
#                                                    SOPartFreq  \
# Respondent
# 3                             A few times per month or weekly
# 8                         Less than once per month or monthly
# 10                                     Multiple times per day
# 13                                     Multiple times per day
# 15                                                        NaN
# ...                                                       ...
# 61561                     Less than once per month or monthly
# 62391                                                     NaN
# 63077       I have never participated in Q&A on Stack Over...
# 63640       I have never participated in Q&A on Stack Over...
# 64867                                                     NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 3                     Daily or almost daily  Neither easy nor difficult
# 8                    Multiple times per day                        Easy
# 10                   Multiple times per day                        Easy
# 13                   Multiple times per day  Neither easy nor difficult
# 15          A few times per month or weekly                        Easy
# ...                                     ...                         ...
# 61561       A few times per month or weekly  Neither easy nor difficult
# 62391                                   NaN  Neither easy nor difficult
# 63077                  A few times per week                         NaN
# 63640       A few times per month or weekly                         NaN
# 64867                                   NaN                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 3           Appropriate in length   NaN
# 8           Appropriate in length    No
# 10          Appropriate in length    No
# 13                       Too long    No
# 15          Appropriate in length    No
# ...                           ...   ...
# 61561       Appropriate in length    No
# 62391                   Too short   NaN
# 63077                         NaN   NaN
# 63640                         NaN    No
# 64867                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 3                                                         NaN
# 8           Computer science, computer engineering, or sof...
# 10                                  Mathematics or statistics
# 13                                                        NaN
# 15          Computer science, computer engineering, or sof...
# ...                                                       ...
# 61561       Information systems, information technology, o...
# 62391                                                     NaN
# 63077       Computer science, computer engineering, or sof...
# 63640                                                     NaN
# 64867                                                     NaN
#
#                                        WebframeDesireNextYear  \
# Respondent
# 3                                                         NaN
# 8                                      Django;React.js;Vue.js
# 10                                               Flask;jQuery
# 13                                                        NaN
# 15                                                        NaN
# ...                                                       ...
# 61561                       Angular.js;jQuery;React.js;Vue.js
# 62391               Angular.js;Express;React.js;Ruby on Rails
# 63077                                                     NaN
# 63640       Angular;Angular.js;Express;jQuery;React.js;Vue.js
# 64867                                                     NaN
#
#                                    WebframeWorkedWith  \
# Respondent
# 3                                                 NaN
# 8                                               Flask
# 10                                       Flask;jQuery
# 13                                                NaN
# 15                                                NaN
# ...                                               ...
# 61561                                          jQuery
# 62391       Angular.js;Express;React.js;Ruby on Rails
# 63077                                             NaN
# 63640                                  Express;jQuery
# 64867                                             NaN
#
#                                        WelcomeChange  WorkWeekHrs  \
# Respondent
# 3           Somewhat more welcome now than last year          NaN
# 8            Just as welcome now as I felt last year         39.0
# 10          Somewhat more welcome now than last year         36.0
# 13             A lot less welcome now than last year         36.0
# 15           Just as welcome now as I felt last year          NaN
# ...                                              ...          ...
# 61561          A lot more welcome now than last year          NaN
# 62391                                            NaN          NaN
# 63077                                            NaN          NaN
# 63640       Somewhat more welcome now than last year          NaN
# 64867                                            NaN          NaN
#
#                    YearsCode      YearsCodePro
# Respondent
# 3                          4               NaN
# 8                         17                13
# 10                         8                 4
# 13                        35                20
# 15                         4               NaN
# ...                      ...               ...
# 61561                     30               NaN
# 62391       Less than 1 year  Less than 1 year
# 63077                      4               NaN
# 63640                      6                 2
# 64867                    NaN               NaN
#
# [25287 rows x 60 columns]
