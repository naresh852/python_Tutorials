# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
filt=df['Country']=='India'
india_df=df.loc[filt]
india_df
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 54757                                          NaN      Yes   NaN         18
# 55407                                          NaN      Yes   NaN        NaN
# 62464                                          NaN      Yes   NaN        NaN
# 62954                                          NaN      Yes   NaN        NaN
# 64236                                          NaN      Yes   NaN        NaN
#
# ...

# %%
india_df.to_csv('data/modifies.csv')

# %%
india_df.to_csv('data/modified.tsv',sep='\t')
# india_df.to_csv('data/modified.tsv',sep='-')

# %%
tsv_df=pd.read_csv('data/modified.tsv',sep='\t')
tsv_df
# Out:
#       Respondent                              MainBranch Hobbyist   Age  \
# 0              7          I am a developer by profession      Yes   NaN
# 1             22          I am a developer by profession      Yes   NaN
# 2             58          I am a developer by profession      Yes   NaN
# 3             63  I am a student who is learning to code      Yes  21.0
# 4            149          I am a developer by profession      Yes  36.0
# ...          ...                                     ...      ...   ...
# 8398       54757                                     NaN      Yes   NaN
# 8399       55407                                     NaN      Yes   NaN
# 8400       62464                                     NaN      Yes   NaN
# 8401       62954                                     NaN      Yes   NaN
# 8402       64236                                     NaN      Yes   NaN
#
#      Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# ...

# %%
india_df.to_excel('data/modified.xlsx')

# %%
test_df=pd.read_excel('data/modified.xlsx',index_col='Respondent')

# %%
test_df
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 54757                                          NaN      Yes   NaN         18
# 55407                                          NaN      Yes   NaN        NaN
# 62464                                          NaN      Yes   NaN        NaN
# 62954                                          NaN      Yes   NaN        NaN
# 64236                                          NaN      Yes   NaN        NaN
#
# ...

# %%
india_df.to_json('data/modified.json',orient='records',lines=True)
# india_df.to_json('data/modified.json')

# %%
test=pd.read_json('data/modified.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-df3f06db8acc> in <module>
# ----> 1 test=pd.read_json('data/modified.json')
#
# c:\users\nares\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# c:\users\nares\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# ...

# %%
test.head()

# %%
test=pd.read_json('data/modified.json',orient='records',lines=True)

# %%
test.head()
# Out:
#                                MainBranch Hobbyist   Age Age1stCode CompFreq  \
# 0          I am a developer by profession      Yes   NaN         18  Monthly
# 1          I am a developer by profession      Yes   NaN         18  Monthly
# 2          I am a developer by profession      Yes   NaN         22     None
# 3  I am a student who is learning to code      Yes  21.0         17     None
# 4          I am a developer by profession      Yes  36.0         31   Yearly
#
#     CompTotal  ConvertedComp Country          CurrencyDesc CurrencySymbol  \
# 0         NaN            NaN   India  United States dollar            USD
# 1         NaN            NaN   India          Indian rupee            INR
# 2         NaN            NaN   India          Indian rupee            INR
# 3         NaN            NaN   India                  None           None
# 4  21000000.0       293196.0   India          Indian rupee            INR
#
#        DatabaseDesireNextYear      DatabaseWorkedWith  \
# ...

# %%
from sqlalchemy import create_engine
import mysql
import mysql.connector

# %%
# engine=create_engine('mysql_query://root:password@localhost:3306/demo')
engine = create_engine("mysqlDb://root:password@localhost/giraffe")
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# <ipython-input-25-633fc695cca6> in <module>
#       1 # engine=create_engine('mysql_query://root:password@localhost:3306/demo')
# ----> 2 engine = create_engine("mysqlDb://root:password@localhost/giraffe")
#       3 import mysql.connector
#
# <string> in create_engine(url, **kwargs)
#
# c:\users\nares\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\util\deprecations.py in warned(fn, *args, **kwargs)
#     296                         stacklevel=3,
#     297                     )
# --> 298             return fn(*args, **kwargs)
#     299
#     300         doc = fn.__doc__ is not None and fn.__doc__ or ""
#
# c:\users\nares\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\engine\create.py in create_engine(url, **kwargs)
#     520     u, plugins, kwargs = u._instantiate_plugins(kwargs)
#     521
# ...

# %%
myconn = mysql.connector.connect(host = "localhost", user = "root",passwd = "password",database='giraffe')

# %%
giraffe_table=pd.read_sql_query('show tables from giraffe',myconn)
giraffe_table
# Out:
#   Tables_in_giraffe
# 0            branch
# 1   branch_supplier
# 2            client
# 3          employee
# 4          stajtion
# 5           station
# 6           student
# 7      trigger_test
# 8        works_with

# %%
giraffe_table1=pd.read_sql_query('select * from branch',myconn)
giraffe_table1
# Out:
#    branch_id branch_name  mgr_id mgr_start_date
# 0          1   Corporate   100.0     2006-02-09
# 1          3    Stamford   106.0     1998-02-13
# 2          4     buffalo     NaN           None

# %%
giraffe_table1['branch_name']  ##error dont do this
# india_df
tables=giraffe_table['Tables_in_giraffe']

# %%
for table in tables:
#     output=pd.read_sql_query("DESCRIBE{}".format(table),myconn)
    output=pd.read_sql_query('select * from {}'.format(table),myconn)
    print(table)
    print(output,'\n')
# Out:
# branch
#    branch_id branch_name  mgr_id mgr_start_date
# 0          1   Corporate   100.0     2006-02-09
# 1          3    Stamford   106.0     1998-02-13
# 2          4     buffalo     NaN           None
#
# branch_supplier
#    branch_id    supplier_name       supply_type
# 0          3      Hammer Mill             Paper
# 1          3    Patriot Paper             Paper
# 2          3  Stamford Lables      Custom Forms
# 3          3         Uni-ball  Writing Utensils
#
# client
#    client_id          client_name  branch_id
# 0        400   Dunmore Highschool        NaN
# 1        401    Lackawana Country        NaN
# 2        402                FedEx        3.0
# 3        403   John Daly Law, LLC        3.0
# 4        404  Scranton Whitepages        NaN
# 5        405      Times Newspaper        3.0
# 6        406                FedEx        NaN
#
# employee
#     emp_id first_name last_name  birth_date sex  salary  super_id  branch_id
# ...

# %%
giraffe_table1['branch_id']
# Out:
# 0    1
# 1    3
# 2    4
# Name: branch_id, dtype: int64

# %%
giraffe_table1['branch_name']
# Out:
# 0    Corporate
# 1     Stamford
# 2      buffalo
# Name: branch_name, dtype: object

# %%
sql_df=pd.read_sql_query('select * from works_with',myconn)
sql_df
# Out:
#    emp_id  client_id  total_sales
# 0     105        400        55000
# 1     105        404        33000
# 2     105        406       130000
# 3     107        403         5000
# 4     107        405        26000
# 5     108        402        22500
# 6     108        403        12000

# %%
cur=myconn.cursor()
cur.execute("create table india_table()")
# india_df.to_sql('india_table',con=myconn)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-43-83ab8856e0e9> in <module>
#       1 cur=myconn.cursor()
# ----> 2 cur.execute("create table india_table()")
#       3 # india_df.to_sql('india_table',con=myconn)
#
# c:\users\nares\appdata\local\programs\python\python39\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     575
#     576         try:
# --> 577             self._handle_result(self._connection.cmd_query(stmt))
#     578         except errors.InterfaceError:
#     579             if self._connection._have_next_result:  # pylint: disable=W0212
#
# c:\users\nares\appdata\local\programs\python\python39\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     693             query = query.encode('utf-8')
#     694         try:
# ...

# %%
engine = create_engine('sqlite:///giraffe.db')

# %%
india_df.to_sql('sample_table', engine, if_exists='replace')

# %%
sql_df = pd.read_sql('sample_table', engine, index_col='Respondent')
sql_df
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 54757                                         None      Yes   NaN         18
# 55407                                         None      Yes   NaN       None
# 62464                                         None      Yes   NaN       None
# 62954                                         None      Yes   NaN       None
# 64236                                         None      Yes   NaN       None
#
# ...

# %%
query=pd.read_sql_query('select * from sample_table',engine,index_col='Respondent')
query
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 54757                                         None      Yes   NaN         18
# 55407                                         None      Yes   NaN       None
# 62464                                         None      Yes   NaN       None
# 62954                                         None      Yes   NaN       None
# 64236                                         None      Yes   NaN       None
#
# ...

# %%
postes_df=pd.read_json('https://raw.githubusercontent.com/CoreyMSchafer/code_snippets/master/Python/Flask_Blog/snippets/posts.json')

# %%
postes_df.head()
# Out:
#                           title  \
# 0               My Updated Post
# 1                 A Second Post
# 2  Top 5 Programming Lanaguages
# 3  Sublime Text Tips and Tricks
# 4              Best Python IDEs
#
#                                              content  user_id
# 0    My first updated post!\r\n\r\nThis is exciting!        1
# 1            This is a post from a different user...        2
# 2  Te melius apeirian postulant cum, labitur admo...        1
# 3  Ea vix dico modus voluptatibus, mel iudico sua...        1
# 4  Elit contentiones nam no, sea ut consul adipis...        1

# %%
engine2 = create_engine('sqlite://')

# %%
query=pd.read_sql_query('select * from sample_table',engine2,index_col='Respondent')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\users\nares\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1704                 if not evt_handled:
# -> 1705                     self.dialect.do_execute(
#    1706                         cursor, statement, parameters, context
#
# c:\users\nares\appdata\local\programs\python\python39\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     680     def do_execute(self, cursor, statement, parameters, context=None):
# --> 681         cursor.execute(statement, parameters)
#     682
#
# OperationalError: no such table: sample_table
#
# The above exception was the direct cause of the following exception:
#
# ...
