# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df['ConvertedComp'].head(50)
# Out:
# Respondent
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8      116000.0
# 9           NaN
# 10      32315.0
# 11      40070.0
# 12      14268.0
# 13      38916.0
# 14      66000.0
# 15          NaN
# 16     108576.0
# 17      79000.0
# 18    1260000.0
# 19      83400.0
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24      91883.0
# 25          NaN
# 26      71093.0
# 27          NaN
# 28          NaN
# 29          NaN
# 30      38778.0
# 31          NaN
# 32      31764.0
# 33      63564.0
# 34          NaN
# 35          NaN
# 36      77556.0
# 37          NaN
# 38      97288.0
# 39          NaN
# 40          NaN
# 41     106000.0
# 42     130000.0
# 43     135000.0
# 44      55893.0
# 45      36753.0
# 46      37834.0
# 47      74970.0
# 48     125000.0
# 49      52000.0
# 50          NaN
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['ConvertedComp'].describe()
# Out:
# count    3.475600e+04
# mean     1.037561e+05
# std      2.268853e+05
# min      0.000000e+00
# 25%      2.464800e+04
# 50%      5.404900e+04
# 75%      9.500000e+04
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].count()
# Out:
# 34756

# %%
df.shape
# Out:
# (64461, 60)

# %%
df['ConvertedComp'].value_counts().head(50)
# Out:
# 120000.0     341
# 100000.0     306
# 150000.0     277
# 1000000.0    258
# 2000000.0    258
# 64859.0      258
# 110000.0     244
# 130000.0     211
# 90000.0      208
# 54049.0      204
# 80000.0      200
# 140000.0     190
# 25944.0      176
# 75669.0      171
# 125000.0     169
# 75000.0      167
# 59454.0      167
# 200000.0     167
# 38916.0      167
# 85000.0      165
# 43239.0      159
# 160000.0     158
# 115000.0     157
# 70264.0      155
# 60000.0      154
# 51888.0      151
# 70000.0      148
# 105000.0     143
# 0.0          142
# 180000.0     142
# 48644.0      142
# 95000.0      124
# 65000.0      124
# 135000.0     123
# 45396.0      120
# 32429.0      119
# 32424.0      116
# 64630.0      113
# 81074.0      107
# 37834.0      105
# 170000.0     103
# 250000.0     101
# 86478.0      101
# 64860.0       95
# 77556.0       92
# 45241.0       92
# 51704.0       88
# 48000.0       87
# 50000.0       87
# 72000.0       86
# Name: ConvertedComp, dtype: int64

# %%
df['ConvertedComp'].count()
# Out:
# 34756

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['LanguageWorkedWith']
# Out:
# Respondent
# 1                                   C#;HTML/CSS;JavaScript
# 2                                         JavaScript;Swift
# 3                                 Objective-C;Python;Swift
# 4                                                      NaN
# 5                                        HTML/CSS;Ruby;SQL
#                                ...
# 64858                                                  NaN
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64898                                                  NaN
# 64925                                             HTML/CSS
# 65112                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
schema_df.loc['LanguageWorkedWith']
# Out:
# QuestionText    Which programming, scripting, and markup langu...
# Name: LanguageWorkedWith, dtype: object

# %%
df['LanguageWorkedWith'].value_counts()
# Out:
# HTML/CSS;JavaScript;PHP;SQL                                       1073
# HTML/CSS;JavaScript                                                900
# C#;HTML/CSS;JavaScript;SQL                                         856
# C#;HTML/CSS;JavaScript;SQL;TypeScript                              754
# HTML/CSS;JavaScript;TypeScript                                     697
#                                                                   ...
# C#;Dart;JavaScript;Rust;TypeScript                                   1
# Bash/Shell/PowerShell;HTML/CSS;JavaScript;Julia;Rust                 1
# Dart;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript                  1
# Bash/Shell/PowerShell;C;C++;Go;Java;JavaScript;Python;Rust;SQL       1
# C#;C++;Java;Kotlin;Python                                            1
# Name: LanguageWorkedWith, Length: 14256, dtype: int64

# %%
df['LanguageWorkedWith'].str.split(';')
# Out:
# Respondent
# 1                               [C#, HTML/CSS, JavaScript]
# 2                                      [JavaScript, Swift]
# 3                             [Objective-C, Python, Swift]
# 4                                                      NaN
# 5                                    [HTML/CSS, Ruby, SQL]
#                                ...
# 64858                                                  NaN
# 64867    [Assembly, Bash/Shell/PowerShell, C, C#, C++, ...
# 64898                                                  NaN
# 64925                                           [HTML/CSS]
# 65112                [C#, HTML/CSS, Java, JavaScript, SQL]
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
df['LanguageWorkedWith'].value_counts(normalize=True)
# Out:
# HTML/CSS;JavaScript;PHP;SQL                                       0.018701
# HTML/CSS;JavaScript                                               0.015685
# C#;HTML/CSS;JavaScript;SQL                                        0.014919
# C#;HTML/CSS;JavaScript;SQL;TypeScript                             0.013141
# HTML/CSS;JavaScript;TypeScript                                    0.012148
#                                                                     ...
# C#;Dart;JavaScript;Rust;TypeScript                                0.000017
# Bash/Shell/PowerShell;HTML/CSS;JavaScript;Julia;Rust              0.000017
# Dart;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript               0.000017
# Bash/Shell/PowerShell;C;C++;Go;Java;JavaScript;Python;Rust;SQL    0.000017
# C#;C++;Java;Kotlin;Python                                         0.000017
# Name: LanguageWorkedWith, Length: 14256, dtype: float64

# %%
df.groupby(['Country'])

# %%
country_grp=df.groupby(['Country'])

# %%
country_grp.get_group('United States')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 8                              I am a developer by profession      Yes  36.0
# 14                             I am a developer by profession      Yes  27.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# ...                                                       ...      ...   ...
# 58498                                                     NaN      Yes  32.0
# 58896                                                     NaN      Yes  29.0
# 60931                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 64858                                                     NaN      Yes   NaN
#
# ...

# %%
filt=df['Country']=='India'
df.loc[filt,'LanguageWorkedWith'].value_counts()
# Out:
# HTML/CSS;JavaScript;PHP;SQL                                    180
# HTML/CSS;JavaScript                                            149
# Java                                                           149
# HTML/CSS;JavaScript;TypeScript                                 121
# Python                                                         103
#                                                               ...
# Bash/Shell/PowerShell;Dart;HTML/CSS;JavaScript;Ruby              1
# Go;Java;JavaScript;PHP;Python;SQL;TypeScript                     1
# Java;Kotlin;Python;R;SQL                                         1
# C;C#;C++;HTML/CSS;JavaScript;Objective-C;PHP;Python;SQL;VBA      1
# C;Java;Scala                                                     1
# Name: LanguageWorkedWith, Length: 2280, dtype: int64

# %%
# country_grp['LanguageWorkedWith'].value_counts().loc['India']
country_grp['LanguageWorkedWith'].value_counts()
# Out:
# Country      LanguageWorkedWith
# Afghanistan  Assembly                                  3
#              HTML/CSS;Java;JavaScript                  2
#              HTML/CSS;Java;JavaScript;PHP;SQL          2
#              HTML/CSS;JavaScript;PHP;SQL               2
#              HTML/CSS;JavaScript;PHP;SQL;TypeScript    2
#                                                       ..
# Zimbabwe     HTML/CSS;JavaScript;Python;SQL            1
#              Java;JavaScript;SQL;TypeScript            1
#              Java;Python                               1
#              JavaScript;Python;VBA                     1
#              PHP                                       1
# Name: LanguageWorkedWith, Length: 33584, dtype: int64

# %%
country_grp['LanguageWorkedWith'].value_counts(normalize=True).loc['India']
# Out:
# LanguageWorkedWith
# HTML/CSS;JavaScript;PHP;SQL       0.026148
# HTML/CSS;JavaScript               0.021644
# Java                              0.021644
# HTML/CSS;JavaScript;TypeScript    0.017577
# Python                            0.014962
#                                     ...
# Python;Rust                       0.000145
# Python;TypeScript                 0.000145
# R                                 0.000145
# R;Ruby                            0.000145
# SQL;Swift                         0.000145
# Name: LanguageWorkedWith, Length: 2280, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 62697.0

# %%
country_grp['ConvertedComp'].agg(['mean','median'])
# Out:
#                                                mean   median
# Country
# Afghanistan                           148290.125000  15163.5
# Albania                                25611.000000  15900.0
# Algeria                                10362.812500   9432.0
# Andorra                                88640.000000  88640.0
# Angola                                  5292.000000   5292.0
# ...                                             ...      ...
# Venezuela, Bolivarian Republic of...    6280.611111   3600.0
# Viet Nam                               28342.605769  10344.0
# Yemen                                  36000.000000  36000.0
# Zambia                                 17506.400000   5452.0
# Zimbabwe                               26338.181818   7200.0
#
# [183 rows x 2 columns]

# %%
country_grp['ConvertedComp'].agg(['mean','median']).loc['Canada']
# Out:
# mean      115101.775465
# median     68068.000000
# Name: Canada, dtype: float64

# %%
filt=df['Country']=='India'
df.loc[filt,'LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 2670

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-cda55dd00399> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# c:\users\nares\appdata\local\programs\python\python39\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
country_respondents=df['Country'].value_counts()
country_respondents
# Out:
# United States                         12469
# India                                  8403
# United Kingdom                         3896
# Germany                                3890
# Canada                                 2191
#                                       ...
# Micronesia, Federated States of...        1
# Fiji                                      1
# Chad                                      1
# Nauru                                     1
# Saint Lucia                               1
# Name: Country, Length: 183, dtype: int64

# %%
people_use_python=country_grp['LanguageWorkedWith'].apply(lambda x:x.str.contains('Python').sum())
people_use_python
# Out:
# Country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: LanguageWorkedWith, Length: 183, dtype: int64

# %%
python_df=pd.concat([country_respondents,people_use_python],axis='columns')
python_df
# Out:
#                                     Country  LanguageWorkedWith
# United States                         12469                5964
# India                                  8403                2670
# United Kingdom                         3896                1621
# Germany                                3890                1712
# Canada                                 2191                1011
# ...                                     ...                 ...
# Micronesia, Federated States of...        1                   1
# Fiji                                      1                   0
# Chad                                      1                   0
# Nauru                                     1                   0
# Saint Lucia                               1                   1
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'Country':'noofrespondents','LanguageWorkedWith':'knowspython'},inplace=True)

# %%
python_df
# Out:
#                                     noofrespondents  knowspython
# United States                                 12469         5964
# India                                          8403         2670
# United Kingdom                                 3896         1621
# Germany                                        3890         1712
# Canada                                         2191         1011
# ...                                             ...          ...
# Micronesia, Federated States of...                1            1
# Fiji                                              1            0
# Chad                                              1            0
# Nauru                                             1            0
# Saint Lucia                                       1            1
#
# [183 rows x 2 columns]

# %%
python_df['pctofpython']=(python_df['knowspython']/python_df['noofrespondents'])*100
python_df
# Out:
#                                     noofrespondents  knowspython  pctofpython
# United States                                 12469         5964    47.830620
# India                                          8403         2670    31.774366
# United Kingdom                                 3896         1621    41.606776
# Germany                                        3890         1712    44.010283
# Canada                                         2191         1011    46.143314
# ...                                             ...          ...          ...
# Micronesia, Federated States of...                1            1   100.000000
# Fiji                                              1            0     0.000000
# Chad                                              1            0     0.000000
# Nauru                                             1            0     0.000000
# Saint Lucia                                       1            1   100.000000
#
# [183 rows x 3 columns]

# %%
python_df.sort_values(by='pctofpython',ascending=False,inplace=True)

# %%
python_df
# Out:
#                                     noofrespondents  knowspython  pctofpython
# Saint Lucia                                       1            1   100.000000
# Gabon                                             1            1   100.000000
# Micronesia, Federated States of...                1            1   100.000000
# Montenegro                                       13            9    69.230769
# Brunei Darussalam                                 3            2    66.666667
# ...                                             ...          ...          ...
# Fiji                                              1            0     0.000000
# Chad                                              1            0     0.000000
# Nauru                                             1            0     0.000000
# Kiribati                                          1            0     0.000000
# Antigua and Barbuda                               2            0     0.000000
#
# [183 rows x 3 columns]

# %%
python_df.head(50)
# Out:
#                                       noofrespondents  knowspython  \
# Saint Lucia                                         1            1
# Gabon                                               1            1
# Micronesia, Federated States of...                  1            1
# Montenegro                                         13            9
# Brunei Darussalam                                   3            2
# Guyana                                              5            3
# Swaziland                                           7            4
# Iceland                                            53           28
# Finland                                           349          183
# Uganda                                             81           42
# Mauritania                                          4            2
# Timor-Leste                                         2            1
# Jamaica                                            14            7
# ...

# %%
python_df.loc['India']
# Out:
# noofrespondents    8403.000000
# knowspython        2670.000000
# pctofpython          31.774366
# Name: India, dtype: float64

# %%
python_df.sort_values(by=['noofrespondents','knowspython'],ascending=[False,False]).head(50)
# Out:
#                     noofrespondents  knowspython  pctofpython
# United States                 12469         5964    47.830620
# India                          8403         2670    31.774366
# United Kingdom                 3896         1621    41.606776
# Germany                        3890         1712    44.010283
# Canada                         2191         1011    46.143314
# France                         1898          833    43.888303
# Brazil                         1818          635    34.928493
# Netherlands                    1343          544    40.506329
# Poland                         1278          509    39.827856
# Australia                      1208          524    43.377483
# Spain                          1161          448    38.587425
# Italy                          1117          422    37.779767
# Russian Federation             1092          421    38.553114
# Sweden                          886          353    39.841986
# ...
